# %%
import pandas as pd
import numpy as np
from calendar import monthrange

# %%
twitch_df = pd.read_csv('Twitch_game_data.csv', encoding='cp1252')

# %%
twitch_df.head()
# Out:
#    Rank                              Game  Month  Year  Hours_watched  \
# 0     1                 League of Legends      1  2016       94377226
# 1     2  Counter-Strike: Global Offensive      1  2016       47832863
# 2     3                            Dota 2      1  2016       45185893
# 3     4                       Hearthstone      1  2016       39936159
# 4     5       Call of Duty: Black Ops III      1  2016       16153057
#
#    Hours_streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# 0         1362044        530270           2903     129172       127021
# 1          830105        372654           2197     120849        64378
# 2          433397        315083           1100      44074        60815
# 3          235903        131357            517      36170        53749
# 4         1151578         71639           3620     214054        21740
#
#    Avg_channels  Avg_viewer_ratio
# 0          1833             69.29
# 1          1117             57.62
# 2           583            104.26
# 3           317            169.29
# 4          1549             14.03

# %%
twitch_df['Month'].describe()
# Out:
# count    17400.000000
# mean         6.344828
# std          3.493370
# min          1.000000
# 25%          3.000000
# 50%          6.000000
# 75%          9.000000
# max         12.000000
# Name: Month, dtype: float64

# %%
twitch_df_global = pd.read_csv('Twitch_global_data.csv', encoding='cp1252')

# %%
twitch_df_global.head()
# Out:
#    year  Month  Hours_watched  Avg_viewers  Peak_viewers  Streams  \
# 0  2016      1      480241904       646355       1275257  7701675
# 1  2016      2      441859897       635769       1308032  7038520
# 2  2016      3      490669308       660389       1591551  7390957
# 3  2016      4      377975447       525696       1775120  6869719
# 4  2016      5      449836631       605432       1438962  7535519
#
#    Avg_channels  Games_streamed  Viewer_ratio
# 0         20076           12149         29.08
# 1         20427           12134         28.98
# 2         20271           12234         28.92
# 3         16791           12282         28.80
# 4         19394           12424         28.85

# %%
twitch_df.describe()
# Out:
#                Rank         Month          Year  Hours_watched  \
# count  17400.000000  17400.000000  17400.000000   1.740000e+04
# mean     100.500000      6.344828   2019.137931   5.406489e+06
# std       57.735964      3.493370      2.096430   1.847645e+07
# min        1.000000      1.000000   2016.000000   8.981100e+04
# 25%       50.750000      3.000000   2017.000000   4.329688e+05
# 50%      100.500000      6.000000   2019.000000   9.594830e+05
# 75%      150.250000      9.000000   2021.000000   2.690568e+06
# max      200.000000     12.000000   2023.000000   3.445520e+08
#
#        Hours_streamed  Peak_viewers  Peak_channels     Streamers  \
# count    1.740000e+04  1.740000e+04   17400.000000  1.740000e+04
# mean     1.740947e+05  6.129193e+04     643.386207  2.082847e+04
# std      5.546933e+05  1.479578e+05    2677.160903  6.298185e+04
# min      1.900000e+01  4.410000e+02       1.000000  0.000000e+00
# 25%      1.414950e+04  9.270000e+03      58.000000  1.724750e+03
# 50%      3.669700e+04  2.228400e+04     141.000000  4.795000e+03
# 75%      9.990650e+04  5.158575e+04     357.000000  1.271675e+04
# max      1.024570e+07  3.366021e+06  129860.000000  1.013324e+06
#
#          Avg_viewers  Avg_channels  Avg_viewer_ratio
# count   17400.000000  17400.000000      17400.000000
# mean     7418.131437    238.397586         76.981366
# std     25362.412291    760.923850        339.203022
# min       120.000000      0.000000          1.670000
# 25%       593.000000     19.000000         16.317500
# 50%      1315.000000     50.000000         29.340000
# 75%      3695.000000    136.000000         57.257500
# max    479209.000000  13789.000000      13601.870000

# %%
'''RNC and DNC are single events, I need to look out for other single events and remove them from the dataset.'''
# Out:
# 'RNC and DNC are single events, I need to look out for other single events and remove them from the dataset.'

# %%
twitch_df[twitch_df['Peak_channels'] == 1]
# Out:
#       Rank      Game  Month  Year  Hours_watched  Hours_streamed  \
# 1329   130  RNC 2016      7  2016         264303              28
#
#       Peak_viewers  Peak_channels  Streamers  Avg_viewers  Avg_channels  \
# 1329         29021              1          2          355             0
#
#       Avg_viewer_ratio
# 1329           9439.39

# %%
twitch_df[twitch_df['Game'] == "DNC 2016"]
# Out:
#       Rank      Game  Month  Year  Hours_watched  Hours_streamed  \
# 1287    88  DNC 2016      7  2016         362702             355
#
#       Peak_viewers  Peak_channels  Streamers  Avg_viewers  Avg_channels  \
# 1287         47549             24         59          488             0
#
#       Avg_viewer_ratio
# 1287            1021.7

# %%
twitch_df.drop([1329, 1287], inplace = True)
twitch_df.reset_index(inplace = True, drop = True)

# %%
#game_list is long, but you can review after downloading code and typing it. Omitted for ease of reading notebook.

# %%
game_list = list(set(list(twitch_df['Game'])))

# %%
'''There were a number of things to review/fix from the the game list on twitch
-- all E3 and twitchcon events are single events and would skew data
-- special characters not appearing correctly are to be fixed
-- review near duplicate games, Final Fantasy XIV and Legend of Zelda Games have some titles that are almost identical. 
    
    As an example there are three versions of Legend of Zelda: Ocarina of time. After some research these are still being streamed
    and tagged as different games so these will not be combined in any fashion. With a similar rationale I did not combine others
    
    Final Fantasy XIV: Online has several different iterations of names. Most are just a function of capitalization and need to
    be consistent. Final Fantasy XIV: Online was chosen. There was one instance of Final Fantasy XIV: Heavensward overlapping 
    with Final Fantasy XIV: Online. If it was just a matter of this one overlapping month I would have left it as is. But given
    that Heavensward is simply an expansion of Final Fantasy Online, Final Fantasy XIV: Heavensward will be changed to 
    Final Fantasy XIV: Online and the one month of overlapping data will be combined. This is because otherwise this would be 
    erroneously categorized as having dropped out of the top 200
    
'''
# Out:
# 'There were a number of things to review/fix from the the game list on twitch\n-- all E3 and twitchcon events are single events and would skew data\n-- special characters not appearing correctly are to be fixed\n-- review near duplicate games, Final Fantasy XIV and Legend of Zelda Games have some titles that are almost identical. \n    \n    As an example there are three versions of Legend of Zelda: Ocarina of time. After some research these are still being streamed\n    and tagged as different games so these will not be combined in any fashion. With a similar rationale I did not combine others\n    \n    Final Fantasy XIV: Online has several different iterations of names. Most are just a function of capitalization and need to\n    be consistent. Final Fantasy XIV: Online was chosen. There was one instance of Final Fantasy XIV: Heavensward overlapping \n    with Final Fantasy XIV: Online. If it was just a matter of this one overlapping month I would have left it as is. But given\n    that Heavensward is simply an expansion of Final Fantasy Online, Final Fantasy XIV: Heavensward will be changed to \n    Final Fantasy XIV: Online and the one month of overlapping data will be combined. This is because otherwise this would be \n    erroneously categorized as having dropped out of the top 200\n    \n'

# %%
twitch_df[twitch_df['Game'].str.contains('TwitchCon') == True]
# Out:
#       Rank            Game  Month  Year  Hours_watched  Hours_streamed  \
# 1761   164  TwitchCon 2016      9  2016         119450             166
# 1848    51  TwitchCon 2016     10  2016         829794             725
# 4259    62  TwitchCon 2017     10  2017         878473            1602
#
#       Peak_viewers  Peak_channels  Streamers  Avg_viewers  Avg_channels  \
# 1761         44758             37         75          166             0
# 1848        125427             40        155         1116             0
# 4259         86285             89        411         1182             2
#
#       Avg_viewer_ratio
# 1761            719.58
# 1848           1144.54
# 4259            548.36

# %%
twitch_df.drop([1761,1848,4259], inplace = True)

# %%
ff_df = twitch_df[twitch_df['Game'].str.contains('XIV') == True]
ff_df.head()
# Out:
#      Rank                            Game  Month  Year  Hours_watched  \
# 111   112  Final Fantasy XIV: Heavensward      1  2016         305520
# 284    85  Final Fantasy XIV: Heavensward      2  2016         358212
# 464    65  Final Fantasy XIV: Heavensward      3  2016         598914
# 688    89  Final Fantasy XIV: Heavensward      4  2016         319118
# 885    86  Final Fantasy XIV: Heavensward      5  2016         305008
#
#      Hours_streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# 111           33688         13084            153       6456          411
# 284           37285          3246            249       6468          515
# 464           43341         17436            193       6615          806
# 688           39940          5466            201       5694          443
# 885           36029         10178            187       5575          410
#
#      Avg_channels  Avg_viewer_ratio
# 111            45              9.07
# 284            53              9.61
# 464            58             13.82
# 688            55              7.99
# 885            48              8.47

# %%
ff_list = list(set(list(ff_df['Game'])))

# %%
ff_list
# Out:
# ['The King of Fighters XIV',
#  'Final Fantasy XIV Online',
#  'FINAL FANTASY XIV Online',
#  'Romance of the Three Kingdoms XIV',
#  'Final Fantasy XIV: Heavensward',
#  'FINAL FANTASY XIV ONLINE']

# %%
ff_list.remove('Romance of the Three Kingdoms XIV')
ff_list.remove('The King of Fighters XIV')

# %%
ff_list
# Out:
# ['Final Fantasy XIV Online',
#  'FINAL FANTASY XIV Online',
#  'Final Fantasy XIV: Heavensward',
#  'FINAL FANTASY XIV ONLINE']

# %%
twitch_df.reset_index(drop = True, inplace = True)

# %%
twitch_df = twitch_df.replace(ff_list, 'Final Fantasy XIV: Online')

# %%
e3_df = twitch_df[twitch_df['Game'].str.contains('E3') == True]
e3_df.index
# Out:
# Int64Index([1005, 3402, 3497, 5801, 5848, 5896], dtype='int64')

# %%
e3_df.describe()
# Out:
#              Rank  Month         Year  Hours_watched  Hours_streamed  \
# count    6.000000    6.0     6.000000   6.000000e+00        6.000000
# mean    46.333333    6.0  2017.333333   8.987702e+06    18801.333333
# std     46.855807    0.0     0.816497   9.571019e+06    24962.272186
# min      6.000000    6.0  2016.000000   3.814990e+05      184.000000
# 25%      7.000000    6.0  2017.000000   8.738742e+05     1327.750000
# 50%     30.500000    6.0  2017.500000   7.549571e+06     9975.000000
# 75%     90.000000    6.0  2018.000000   1.414050e+07    24437.750000
# max    102.000000    6.0  2018.000000   2.345944e+07    64970.000000
#
#        Peak_viewers  Peak_channels     Streamers   Avg_viewers  Avg_channels  \
# count  6.000000e+00       6.000000      6.000000      6.000000      6.000000
# mean   8.606043e+05    1698.166667   3930.333333  12499.666667     25.666667
# std    5.482893e+05    1843.020935   4964.879280  13311.487094     34.714070
# min    3.882860e+05     177.000000    186.000000    530.000000      0.000000
# 25%    4.375315e+05     408.500000    704.000000   1215.000000      1.250000
# 50%    7.290035e+05    1263.500000   2300.000000  10499.500000     13.500000
# 75%    1.051961e+06    1993.250000   4533.500000  19666.250000     33.250000
# max    1.817345e+06    5125.000000  13346.000000  32627.000000     90.000000
#
#        Avg_viewer_ratio
# count          6.000000
# mean         917.033333
# std          665.143713
# min          361.080000
# 25%          434.635000
# 50%          683.405000
# 75%         1182.780000
# max         2073.360000

# %%
twitch_df.drop(e3_df.index, inplace = True)

# %%
twitch_df.drop(twitch_df[twitch_df['Game'] == 'Twitch Presents'].index, inplace = True)
twitch_df.reset_index(inplace = True, drop = True)

# %%
'''One thing that surprises me is the amount of classic games in this dataset. This will change the nature of the analysis in 
that games that are popular are not necessarily new so having a recent release date will likely negatively impact future 
popularity. 
'''
# Out:
# 'One thing that surprises me is the amount of classic games in this dataset. This will change the nature of the analysis in \nthat games that are popular are not necessarily new so having a recent release date will likely negatively impact future \npopularity. \n'

# %%
twitch_df[twitch_df['Game'] =='Phoenix Wright: Ace Attorney <U+2212> Spirit of Justice']
# Out:
#       Rank                                               Game  Month  Year  \
# 1791   196  Phoenix Wright: Ace Attorney <U+2212> Spirit o...      9  2016
#
#       Hours_watched  Hours_streamed  Peak_viewers  Peak_channels  Streamers  \
# 1791          96620             842          2287              8         56
#
#       Avg_viewers  Avg_channels  Avg_viewer_ratio
# 1791          134             1            114.75

# %%
twitch_df = twitch_df.replace('Phoenix Wright: Ace Attorney <U+2212> Spirit of Justice', 'Phoenix Wright: Ace Attorney - Spirit of Justice')

# %%
twitch_df[twitch_df['Game'] =='Phoenix Wright: Ace Attorney - Spirit of Justice']
# Out:
#       Rank                                              Game  Month  Year  \
# 1791   196  Phoenix Wright: Ace Attorney - Spirit of Justice      9  2016
#
#       Hours_watched  Hours_streamed  Peak_viewers  Peak_channels  Streamers  \
# 1791          96620             842          2287              8         56
#
#       Avg_viewers  Avg_channels  Avg_viewer_ratio
# 1791          134             1            114.75

# %%
poke_df = twitch_df[twitch_df['Game'].str.contains('Pok') == True]
poke_df.head(10)
# Out:
#      Rank                                      Game  Month  Year  \
# 21     22                                     Poker      1  2016
# 50     51  Pok<U+00E9>mon Omega Ruby/Alpha Sapphire      1  2016
# 78     79                   Pok<U+00E9>mon Red/Blue      1  2016
# 79     80                     Pok<U+00E9>mon Yellow      1  2016
# 226    27                                     Poker      2  2016
# 252    53  Pok<U+00E9>mon Omega Ruby/Alpha Sapphire      2  2016
# 321   122                   Pok<U+00E9>mon Red/Blue      2  2016
# 377   178          Pok<U+00E9>mon FireRed/LeafGreen      2  2016
# 422    23                                     Poker      3  2016
# 444    45  Pok<U+00E9>mon Omega Ruby/Alpha Sapphire      3  2016
#
#      Hours_watched  Hours_streamed  Peak_viewers  Peak_channels  Streamers  \
# 21         3151063           36445         18034            126       2527
# 50          992216           20237         11278             61       1428
# 78          456370            3276        185106             40        540
# 79          449878             855        210369             40        205
# 226        2465052           36936         14039            115       2458
# 252        1014081           17894         16439             59       1510
# 321         192855            4838         20162             53        865
# 377         117710            3260         18360             21        803
# 422        3534525           41966         25720            176       2592
# 444        1246547           24192          6980             64       1861
#
#      Avg_viewers  Avg_channels  Avg_viewer_ratio
# 21          4241            49             86.46
# 50          1335            27             49.03
# 78           614             4            139.31
# 79           605             1            526.17
# 226         3546            53             66.74
# 252         1459            25             56.67
# 321          277             6             39.86
# 377          169             4             36.11
# 422         4757            56             84.22
# 444         1677            32             51.53

# %%
poke_list = list(set(list(poke_df['Game'])))

# %%
poke_list.remove('Poker')
poke_list.remove('Prominence Poker')

# %%
twitch_df.reset_index(drop = True, inplace = True)

# %%
def clean (string):
    lst = []
    for letter in string:
        lst.append(letter)
    if '<' in lst:
        index = lst.index('<')
        del lst[index:index + 8]
        lst.insert(index, 'e')
        lst = ''.join(lst)
        return(lst)
    if 'Ã' in lst:
        index = lst.index('Ã')
        del lst[index:index + 2]
        lst.insert(index, 'e')
        lst = ''.join(lst)
        return(lst)
    else:
        lst = ''.join(lst)
        return(lst)

# %%
x = len(twitch_df)
for i in range(x):
    twitch_df['Game'][i] = str(twitch_df['Game'][i])
    twitch_df['Game'][i] = clean(twitch_df['Game'][i])
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_2572\1143704737.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   twitch_df['Game'][i] = str(twitch_df['Game'][i])
# C:\Users\danie\AppData\Local\Temp\ipykernel_2572\1143704737.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   twitch_df['Game'][i] = clean(twitch_df['Game'][i])

# %%
poke_list[0]
# Out:
# 'Pok<U+00E9>mon X/Y'

# %%
poke_df = twitch_df[twitch_df['Game'].str.contains('Pok') == True]
poke_df.head(10)
# Out:
#      Rank                               Game  Month  Year  Hours_watched  \
# 21     22                              Poker      1  2016        3151063
# 50     51  Pokemon Omega Ruby/Alpha Sapphire      1  2016         992216
# 78     79                   Pokemon Red/Blue      1  2016         456370
# 79     80                     Pokemon Yellow      1  2016         449878
# 226    27                              Poker      2  2016        2465052
# 252    53  Pokemon Omega Ruby/Alpha Sapphire      2  2016        1014081
# 321   122                   Pokemon Red/Blue      2  2016         192855
# 377   178          Pokemon FireRed/LeafGreen      2  2016         117710
# 422    23                              Poker      3  2016        3534525
# 444    45  Pokemon Omega Ruby/Alpha Sapphire      3  2016        1246547
#
#      Hours_streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# 21            36445         18034            126       2527         4241
# 50            20237         11278             61       1428         1335
# 78             3276        185106             40        540          614
# 79              855        210369             40        205          605
# 226           36936         14039            115       2458         3546
# 252           17894         16439             59       1510         1459
# 321            4838         20162             53        865          277
# 377            3260         18360             21        803          169
# 422           41966         25720            176       2592         4757
# 444           24192          6980             64       1861         1677
#
#      Avg_channels  Avg_viewer_ratio
# 21             49             86.46
# 50             27             49.03
# 78              4            139.31
# 79              1            526.17
# 226            53             66.74
# 252            25             56.67
# 321             6             39.86
# 377             4             36.11
# 422            56             84.22
# 444            32             51.53

# %%
twitch_df.head()
# Out:
#    Rank                              Game  Month  Year  Hours_watched  \
# 0     1                 League of Legends      1  2016       94377226
# 1     2  Counter-Strike: Global Offensive      1  2016       47832863
# 2     3                            Dota 2      1  2016       45185893
# 3     4                       Hearthstone      1  2016       39936159
# 4     5       Call of Duty: Black Ops III      1  2016       16153057
#
#    Hours_streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# 0         1362044        530270           2903     129172       127021
# 1          830105        372654           2197     120849        64378
# 2          433397        315083           1100      44074        60815
# 3          235903        131357            517      36170        53749
# 4         1151578         71639           3620     214054        21740
#
#    Avg_channels  Avg_viewer_ratio
# 0          1833             69.29
# 1          1117             57.62
# 2           583            104.26
# 3           317            169.29
# 4          1549             14.03

# %%
#As a result of fixing the pokemon games God of War Ragnarok was changed, but still incorrect. The below fixes this

# %%
gow_df = twitch_df[twitch_df['Game'].str.contains('Ragnarek') == True]

# %%
gow_df
# Out:
#        Rank                 Game  Month  Year  Hours_watched  Hours_streamed  \
# 16392    11  God of War Ragnarek     11  2022       40440752         1617975
# 16637    56  God of War Ragnarek     12  2022        3798888          477077
# 16869    88  God of War Ragnarek      1  2023        1727833          257951
# 17175   194  God of War Ragnarek      2  2023         552004          122533
#
#        Peak_viewers  Peak_channels  Streamers  Avg_viewers  Avg_channels  \
# 16392        480655          11583     136899        56245          2250
# 16637         34187           1673      65383         5112           642
# 16869         26831            866      40012         2325           347
# 17175          7011            449      22703          822           182
#
#        Avg_viewer_ratio
# 16392             24.99
# 16637              7.96
# 16869              6.70
# 17175              4.50

# %%
twitch_df = twitch_df.replace('God of War Ragnarek', 'God of War Ragnarok')

# %%
#As a result of fixing the pokemon games Okami was changed, but incorrectly, the below fixes that

# %%
okami_df = twitch_df[twitch_df['Game'].str.contains('kami') == True]
okami_df
# Out:
#        Rank                                               Game  Month  Year  \
# 4773    185                                              ekami     12  2017
# 13887   106  Demon Slayer -Kimetsu no Yaiba- The Hinokami C...     10  2021
#
#        Hours_watched  Hours_streamed  Peak_viewers  Peak_channels  Streamers  \
# 4773          181539           19273         29429            148       3305
# 13887        1641397           93397         57275            950      15889
#
#        Avg_viewers  Avg_channels  Avg_viewer_ratio
# 4773           244            25              9.42
# 13887         2209           125             17.57

# %%
twitch_df = twitch_df.replace('ekami', 'Okami')

# %%
twitch_df.reset_index(drop = True, inplace = True)

# %%
twitch_df = twitch_df.sort_values(by = ['Game', 'Year', 'Month'])
twitch_df.head(10)
twitch_df.reset_index(drop = True, inplace = True)

# %%
x = len(twitch_df)
dup_l = []
for i in range(x-1):
    if twitch_df['Game'][i] == twitch_df['Game'][i+1] and twitch_df['Month'][i] == twitch_df['Month'][i+1] and twitch_df['Year'][i] == twitch_df['Year'][i+1]:
        dup_l.append(i)

# %%
dup_l
# Out:
# [518, 872, 3894, 4970, 11111, 11120, 11173, 11289, 11291, 13076]

# %%
examine = twitch_df.filter(items = dup_l, axis=0)
examine = examine.sort_values(by = ['Game', 'Year', 'Month'])

# %%
'''As we can see by the dataframe below there are a lot of duplicates, these will also have to be combined in some fashion.
One challenge in this is that Peak_viewers, Peak_channels, and Streamers are not computable. 
I will choose the max value of each. 

For consistency I should compute the average viewers, channels, and viewer_ratio based 
on the other columns in the dataframe for all columns.'''
# Out:
# 'As we can see by the dataframe below there are a lot of duplicates, these will also have to be combined in some fashion.\nOne challenge in this is that Peak_viewers, Peak_channels, and Streamers are not computable. \nI will choose the max value of each. \n\nFor consistency I should compute the average viewers, channels, and viewer_ratio based \non the other columns in the dataframe for all columns.'

# %%
examine
# Out:
#        Rank                       Game  Month  Year  Hours_watched  \
# 518      68                   Among Us      1  2023        2760266
# 872      15                      Atlas      1  2019       12110031
# 3894     75         Dungeons & Dragons      9  2018         790966
# 4970     86  Final Fantasy XIV: Online      5  2017         533590
# 11111   116              Resident Evil     10  2016         251183
# 11120    13            Resident Evil 2      1  2019       16394917
# 11173    11            Resident Evil 4      3  2023       27426481
# 11289    72                      Retro      9  2021        2976840
# 11291    83                      Retro     10  2021        2484523
# 13076    27                      Stray      7  2022       11428809
#
#        Hours_streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# 518             76925        137287            342      37885         3715
# 872            187032         69614            637      10070        16298
# 3894            21961         38597            181       2876         1100
# 4970            28073         35091            189       3965          718
# 11111            3976          9871             21       7420          338
# 11120          449333        314244           6488      70644        22065
# 11173         1054133        327946          12902     137994        36913
# 11289          131077         20554            424       8577         4140
# 11291           97914         10543            321       8118         3343
# 13076          508590        287683           7662     136947        15381
#
#        Avg_channels  Avg_viewer_ratio
# 518             103             35.88
# 872             251             64.75
# 3894             30             36.02
# 4970             37             19.01
# 11111             5             63.17
# 11120           604             36.49
# 11173          1418             26.02
# 11289           182             22.71
# 11291           131             25.37
# 13076           684             22.47

# %%
new_values= []
def add_col(col):
    new_values.clear()
    for i in dup_l:
        new_values.append(twitch_df[col][i] + twitch_df[col][i+1])

# %%
add_col('Hours_watched')

# %%
x = len(new_values)
def replace_cols(cols):
    for i in range(x):
        twitch_df.replace(twitch_df[cols][dup_l[i]], new_values[i], inplace = True)

# %%
replace_cols('Hours_watched')

# %%
twitch_df['Hours_watched'][518]
# Out:
# 3636990

# %%
add_col('Hours_streamed')

# %%
replace_cols('Hours_streamed')

# %%
def higher(col):
    new_values.clear()
    for i in dup_l:
        if twitch_df[col][i] > twitch_df[col][i+1]:
            new_values.append(twitch_df[col][i])
        else:
            new_values.append(twitch_df[col][i+1])

# %%
higher('Peak_viewers')

# %%
replace_cols('Peak_viewers')

# %%
higher('Peak_channels')

# %%
replace_cols('Peak_channels')

# %%
higher('Streamers')

# %%
replace_cols('Streamers')

# %%
'''
(Hours watched/hours in the month) is approximately the same as the current Avg_viewers; 
(Hours streamed/hours in the month) is approximately the same as Avg_channels;

Avg_viewer_ratio is (Avg_viewers/Avg_channels); however when computing with the values I found that I was sometimes dividing
by 0. To use these values I simply reversed the division to Avg_channels/Avg_viewers.

I will be using these values instead given there are some duplicates not of my own making that needed combined.
Also, the data card was not forthcoming as to the provenance of these columns. Creating my own similar metrics
makes sense. 

Rank will not be helpful at this point so I will remove'''
# Out:
# '\n(Hours watched/hours in the month) is approximately the same as the current Avg_viewers; \n(Hours streamed/hours in the month) is approximately the same as Avg_channels;\n\nAvg_viewer_ratio is (Avg_viewers/Avg_channels); however when computing with the values I found that I was sometimes dividing\nby 0. To use these values I simply reversed the division to Avg_channels/Avg_viewers.\n\nI will be using these values instead given there are some duplicates not of my own making that needed combined.\nAlso, the data card was not forthcoming as to the provenance of these columns. Creating my own similar metrics\nmakes sense. \n\nRank will not be helpful at this point so I will remove'

# %%
no_leap = []
leap = []
for i in range(1,13):
    leap.append(monthrange(2004, i)[1] * 24)
    no_leap.append(monthrange(2003, i)[1] * 24)

# %%
no_leap
# Out:
# [744, 672, 744, 720, 744, 720, 744, 744, 720, 744, 720, 744]

# %%
leap
# Out:
# [744, 696, 744, 720, 744, 720, 744, 744, 720, 744, 720, 744]

# %%
x = len(twitch_df)
month_hours = []
for i in range(x):
    if twitch_df['Year'][i] %4:
        hours = leap[(twitch_df['Month'][i]-1)]
        month_hours.append(hours)
    else:
        hours = no_leap[(twitch_df['Month'][i]-1)]
        month_hours.append(hours)

# %%
twitch_df['Month_hours'] = month_hours
twitch_df.head()
# Out:
#    Rank                     Game  Month  Year  Hours_watched  Hours_streamed  \
# 0   199  .hack//G.U. Last Recode     11  2017         145350           35258
# 1   159     20 Minutes Till Dawn      6  2022         911356           12253
# 2   109              60 Parsecs!      9  2018         529688            1867
# 3   126              60 Seconds!      7  2016         268754             597
# 4    54              60 Seconds!      8  2016         772786            2065
#
#    Peak_viewers  Peak_channels  Streamers  Avg_viewers  Avg_channels  \
# 0          1222            258       3174          202            49
# 1         29743             80       3616         1267            17
# 2         31960             27        606          736             2
# 3         32505             10        275          361             0
# 4         56904             30        628         1040             2
#
#    Avg_viewer_ratio  Month_hours
# 0              4.12          720
# 1             74.38          720
# 2            283.71          720
# 3            450.17          744
# 4            374.23          744

# %%
twitch_df['Avg_viewers'] = round(twitch_df['Hours_watched']/twitch_df['Month_hours'])
twitch_df.head()
# Out:
#    Rank                     Game  Month  Year  Hours_watched  Hours_streamed  \
# 0   199  .hack//G.U. Last Recode     11  2017         145350           35258
# 1   159     20 Minutes Till Dawn      6  2022         911356           12253
# 2   109              60 Parsecs!      9  2018         529688            1867
# 3   126              60 Seconds!      7  2016         268754             597
# 4    54              60 Seconds!      8  2016         772786            2065
#
#    Peak_viewers  Peak_channels  Streamers  Avg_viewers  Avg_channels  \
# 0          1222            258       3174        202.0            49
# 1         29743             80       3616       1266.0            17
# 2         31960             27        606        736.0             2
# 3         32505             10        275        361.0             0
# 4         56904             30        628       1039.0             2
#
#    Avg_viewer_ratio  Month_hours
# 0              4.12          720
# 1             74.38          720
# 2            283.71          720
# 3            450.17          744
# 4            374.23          744

# %%
twitch_df['Avg_channels'] = round(twitch_df['Hours_streamed']/twitch_df['Month_hours'])
twitch_df.head()
# Out:
#    Rank                     Game  Month  Year  Hours_watched  Hours_streamed  \
# 0   199  .hack//G.U. Last Recode     11  2017         145350           35258
# 1   159     20 Minutes Till Dawn      6  2022         911356           12253
# 2   109              60 Parsecs!      9  2018         529688            1867
# 3   126              60 Seconds!      7  2016         268754             597
# 4    54              60 Seconds!      8  2016         772786            2065
#
#    Peak_viewers  Peak_channels  Streamers  Avg_viewers  Avg_channels  \
# 0          1222            258       3174        202.0          49.0
# 1         29743             80       3616       1266.0          17.0
# 2         31960             27        606        736.0           3.0
# 3         32505             10        275        361.0           1.0
# 4         56904             30        628       1039.0           3.0
#
#    Avg_viewer_ratio  Month_hours
# 0              4.12          720
# 1             74.38          720
# 2            283.71          720
# 3            450.17          744
# 4            374.23          744

# %%
twitch_df['Avg_channel_ratio'] = round(twitch_df['Avg_channels']/twitch_df['Avg_viewers'],2)
twitch_df.head()
# Out:
#    Rank                     Game  Month  Year  Hours_watched  Hours_streamed  \
# 0   199  .hack//G.U. Last Recode     11  2017         145350           35258
# 1   159     20 Minutes Till Dawn      6  2022         911356           12253
# 2   109              60 Parsecs!      9  2018         529688            1867
# 3   126              60 Seconds!      7  2016         268754             597
# 4    54              60 Seconds!      8  2016         772786            2065
#
#    Peak_viewers  Peak_channels  Streamers  Avg_viewers  Avg_channels  \
# 0          1222            258       3174        202.0          49.0
# 1         29743             80       3616       1266.0          17.0
# 2         31960             27        606        736.0           3.0
# 3         32505             10        275        361.0           1.0
# 4         56904             30        628       1039.0           3.0
#
#    Avg_viewer_ratio  Month_hours  Avg_channel_ratio
# 0              4.12          720               0.24
# 1             74.38          720               0.01
# 2            283.71          720               0.00
# 3            450.17          744               0.00
# 4            374.23          744               0.00

# %%
twitch_df.drop(twitch_df[twitch_df['Game'] == 'Twitch Presents'].index, inplace = True)
twitch_df.reset_index(inplace = True, drop = True)

# %%
twitch_df.sort_values(by = ['Month', 'Year', 'Game'], inplace = True)
twitch_df.head(20)
# Out:
#       Rank                                           Game  Month  Year  \
# 12     129                                  7 Days to Die      1  2016
# 258    138                                        Agar.io      1  2016
# 264    142                                 Age of Empires      1  2016
# 422    135                               Alien: Isolation      1  2016
# 477    108                       American Truck Simulator      1  2016
# 694     30                          Ark: Survival Evolved      1  2016
# 718     26                                         Arma 3      1  2016
# 911    171                          Azure Striker GUNVOLT      1  2016
# 928    148                                  Banjo-Kazooie      1  2016
# 967    101                            BattleBlock Theater      1  2016
# 1011    61                                  Battlefield 4      1  2016
# 1139   104                            Black Desert Online      1  2016
# 1227    14                                   Blade & Soul      1  2016
# 1268   185                                    Blast Corps      1  2016
# 1287    43                                     Bloodborne      1  2016
# 1403   191                                  Borderlands 2      1  2016
# 1465   196  Brain Age: Train Your Brain in Minutes a Day!      1  2016
# 1661   110                     Call of Duty: Black Ops II      1  2016
# 1679     5                    Call of Duty: Black Ops III      1  2016
# 2031   197                               Cities: Skylines      1  2016
#
#       Hours_watched  Hours_streamed  Peak_viewers  Peak_channels  Streamers  \
# 12           269681           12131          4405             44       1240
# 258          255617           20705          4183             74       4472
# 264          248884             232        107455             18         40
# 422          264294           11799          9590             42       3968
# 477          314055             724         43089             48        186
# 694         1951875           93060         19486            241       9575
# 718         2542838           86219         32132            275       8771
# 911          197178             217        135933             14         71
# 928          241250            2234        108131             28        547
# 967          332256            2041        152739             19       1097
# 1011         672524           96185          6349            271      21087
# 1139         320675           15798          1888             44       1416
# 1227        5270251          184279         67256           1099      22637
# 1268         178810              42         96318             18         25
# 1287        1300353           86384        199060            257      17349
# 1403         175135           21849          3376             71       4039
# 1465         173011              19        207721             14         31
# 1661         309850           29294          4491            100       4841
# 1679       16153057         1151578         71639           3620     214054
# 2031         172577            8602          7371             30       1827
#
#       Avg_viewers  Avg_channels  Avg_viewer_ratio  Month_hours  \
# 12          362.0          16.0             22.23          744
# 258         344.0          28.0             12.35          744
# 264         335.0           0.0           1072.78          744
# 422         355.0          16.0             22.40          744
# 477         422.0           1.0            433.78          744
# 694        2623.0         125.0             20.97          744
# 718        3418.0         116.0             29.49          744
# 911         265.0           0.0            908.65          744
# 928         324.0           3.0            107.99          744
# 967         447.0           3.0            162.79          744
# 1011        904.0         129.0              6.99          744
# 1139        431.0          21.0             20.30          744
# 1227       7084.0         248.0             28.60          744
# 1268        240.0           0.0           4257.38          744
# 1287       1748.0         116.0             15.05          744
# 1403        235.0          29.0              8.02          744
# 1465        233.0           0.0           9105.84          744
# 1661        416.0          39.0             10.58          744
# 1679      21711.0        1548.0             14.03          744
# 2031        232.0          12.0             20.06          744
#
#       Avg_channel_ratio
# 12                 0.04
# 258                0.08
# 264                0.00
# 422                0.05
# 477                0.00
# 694                0.05
# 718                0.03
# 911                0.00
# 928                0.01
# 967                0.01
# 1011               0.14
# 1139               0.05
# 1227               0.04
# 1268               0.00
# 1287               0.07
# 1403               0.12
# 1465               0.00
# 1661               0.09
# 1679               0.07
# 2031               0.05

# %%
df = list(twitch_df.Year.astype(str) + '/' + twitch_df.Month.astype(str) + '/01')
twitch_df['Date'] = df
twitch_df['Date']= pd.to_datetime(twitch_df['Date'])

# %%
twitch_df_X = twitch_df.drop_duplicates(subset=['Game'])
twitch_df_X.head(10)
# Out:
#      Rank                      Game  Month  Year  Hours_watched  \
# 12    129             7 Days to Die      1  2016         269681
# 258   138                   Agar.io      1  2016         255617
# 264   142            Age of Empires      1  2016         248884
# 422   135          Alien: Isolation      1  2016         264294
# 477   108  American Truck Simulator      1  2016         314055
# 694    30     Ark: Survival Evolved      1  2016        1951875
# 718    26                    Arma 3      1  2016        2542838
# 911   171     Azure Striker GUNVOLT      1  2016         197178
# 928   148             Banjo-Kazooie      1  2016         241250
# 967   101       BattleBlock Theater      1  2016         332256
#
#      Hours_streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# 12            12131          4405             44       1240        362.0
# 258           20705          4183             74       4472        344.0
# 264             232        107455             18         40        335.0
# 422           11799          9590             42       3968        355.0
# 477             724         43089             48        186        422.0
# 694           93060         19486            241       9575       2623.0
# 718           86219         32132            275       8771       3418.0
# 911             217        135933             14         71        265.0
# 928            2234        108131             28        547        324.0
# 967            2041        152739             19       1097        447.0
#
#      Avg_channels  Avg_viewer_ratio  Month_hours  Avg_channel_ratio       Date
# 12           16.0             22.23          744               0.04 2016-01-01
# 258          28.0             12.35          744               0.08 2016-01-01
# 264           0.0           1072.78          744               0.00 2016-01-01
# 422          16.0             22.40          744               0.05 2016-01-01
# 477           1.0            433.78          744               0.00 2016-01-01
# 694         125.0             20.97          744               0.05 2016-01-01
# 718         116.0             29.49          744               0.03 2016-01-01
# 911           0.0            908.65          744               0.00 2016-01-01
# 928           3.0            107.99          744               0.01 2016-01-01
# 967           3.0            162.79          744               0.01 2016-01-01

# %%
twitch_df_X.describe()
# Out:
#               Rank        Month         Year  Hours_watched  Hours_streamed  \
# count  2025.000000  2025.000000  2025.000000   2.025000e+03    2.025000e+03
# mean    123.389136     4.402469  2018.737778   1.722624e+06    5.265007e+04
# std      53.193534     3.545371     2.247062   5.395172e+06    2.188540e+05
# min       1.000000     1.000000  2016.000000   9.246000e+04    1.900000e+01
# 25%      82.000000     1.000000  2017.000000   2.719870e+05    2.857000e+03
# 50%     130.000000     3.000000  2018.000000   6.132720e+05    1.046700e+04
# 75%     171.000000     7.000000  2021.000000   1.235417e+06    3.050200e+04
# max     200.000000    12.000000  2023.000000   9.437723e+07    4.948200e+06
#
#        Peak_viewers  Peak_channels      Streamers    Avg_viewers  \
# count  2.025000e+03    2025.000000    2025.000000    2025.000000
# mean   5.925928e+04     342.406420    7975.665679    2341.547654
# std    9.022342e+04    1071.912494   25987.858807    7321.015681
# min    7.470000e+02       2.000000       0.000000     126.000000
# 25%    1.644000e+04      26.000000     501.000000     369.000000
# 50%    3.332000e+04      76.000000    1802.000000     834.000000
# 75%    6.725600e+04     233.000000    5459.000000    1704.000000
# max    1.832845e+06   29306.000000  469399.000000  126851.000000
#
#        Avg_channels  Avg_viewer_ratio  Month_hours  Avg_channel_ratio
# count   2025.000000       2025.000000  2025.000000        2025.000000
# mean      71.471605        253.404770   733.179259           0.026716
# std      297.343688        808.080268    18.413132           0.035082
# min        0.000000          2.270000   672.000000           0.000000
# 25%        4.000000         31.420000   720.000000           0.010000
# 50%       14.000000         61.070000   744.000000           0.020000
# 75%       42.000000        148.010000   744.000000           0.030000
# max     6651.000000      11457.470000   744.000000           0.440000

# %%
zero_df = twitch_df[twitch_df['Avg_channels'] == 0]
zero_df.head(11)
# Out:
#       Rank                                           Game  Month  Year  \
# 264    142                                 Age of Empires      1  2016
# 911    171                          Azure Striker GUNVOLT      1  2016
# 1268   185                                    Blast Corps      1  2016
# 1465   196  Brain Age: Train Your Brain in Minutes a Day!      1  2016
# 6404    86                          Half Life 2: Survivor      1  2016
# 7098   184                                            Iji      1  2016
# 7470   107                   Kirby 64: The Crystal Shards      1  2016
# 7478   114                            Kirby: Squeak Squad      1  2016
# 8690   172                                    Mega Man 10      1  2016
# 8862   170                       Mike Tyson's Punch-Out!!      1  2016
# 9502   180     Ninja Gaiden III: The Ancient Ship of Doom      1  2016
#
#       Hours_watched  Hours_streamed  Peak_viewers  Peak_channels  Streamers  \
# 264          248884             232        107455             18         40
# 911          197178             217        135933             14         71
# 1268         178810              42         96318             18         25
# 1465         173011              19        207721             14         31
# 6404         400106             195        164561             17         81
# 7098         179556              30         91449             16         22
# 7470         315368             209        158893             16         58
# 7478         299628              60        156564             16         28
# 8690         197038             141        158783             29         55
# 8862         197881             307        168929             30        105
# 9502         183550             122        133273             16         36
#
#       Avg_viewers  Avg_channels  Avg_viewer_ratio  Month_hours  \
# 264         335.0           0.0           1072.78          744
# 911         265.0           0.0            908.65          744
# 1268        240.0           0.0           4257.38          744
# 1465        233.0           0.0           9105.84          744
# 6404        538.0           0.0           2051.83          744
# 7098        241.0           0.0           5985.20          744
# 7470        424.0           0.0           1508.94          744
# 7478        403.0           0.0           4993.80          744
# 8690        265.0           0.0           1397.43          744
# 8862        266.0           0.0            644.56          744
# 9502        247.0           0.0           1504.51          744
#
#       Avg_channel_ratio       Date
# 264                 0.0 2016-01-01
# 911                 0.0 2016-01-01
# 1268                0.0 2016-01-01
# 1465                0.0 2016-01-01
# 6404                0.0 2016-01-01
# 7098                0.0 2016-01-01
# 7470                0.0 2016-01-01
# 7478                0.0 2016-01-01
# 8690                0.0 2016-01-01
# 8862                0.0 2016-01-01
# 9502                0.0 2016-01-01

# %%
one_df = twitch_df[twitch_df['Avg_channels'] == 1]
one_df.head(11)
# Out:
#       Rank                                       Game  Month  Year  \
# 477    108                   American Truck Simulator      1  2016
# 2354    87                            Crash Bandicoot      1  2016
# 2865   147                              Darksiders II      1  2016
# 3650   146                        Donkey Kong Country      1  2016
# 3652   106  Donkey Kong Country 2: Diddy's Kong Quest      1  2016
# 5059   150              Fire Emblem: Path of Radiance      1  2016
# 6411   113                                     Halo 4      1  2016
# 7983    89                                  M.U.G.E.N      1  2016
# 8211   181                                Mafia LIVE!      1  2016
# 8531   193                              Mario Kart 64      1  2016
# 8788   153                             Metroid Fusion      1  2016
#
#       Hours_watched  Hours_streamed  Peak_viewers  Peak_channels  Streamers  \
# 477          314055             724         43089             48        186
# 2354         399886             501        159957             29        172
# 2865         242099             752        120528             11        502
# 3650         243490             826        160369             17        288
# 3652         316101             993        181740             28        218
# 5059         235555             516        122456             10         65
# 6411         302218             569        135671             13         71
# 7983         386581             944           976              5         66
# 8211         183378             772          9532              8         73
# 8531         173981             605        186466             31        220
# 8788         234149             587        147009             22        147
#
#       Avg_viewers  Avg_channels  Avg_viewer_ratio  Month_hours  \
# 477         422.0           1.0            433.78          744
# 2354        537.0           1.0            798.18          744
# 2865        325.0           1.0            321.94          744
# 3650        327.0           1.0            294.78          744
# 3652        425.0           1.0            318.33          744
# 5059        317.0           1.0            456.50          744
# 6411        406.0           1.0            531.14          744
# 7983        520.0           1.0            409.51          744
# 8211        246.0           1.0            237.54          744
# 8531        234.0           1.0            287.57          744
# 8788        315.0           1.0            398.89          744
#
#       Avg_channel_ratio       Date
# 477                 0.0 2016-01-01
# 2354                0.0 2016-01-01
# 2865                0.0 2016-01-01
# 3650                0.0 2016-01-01
# 3652                0.0 2016-01-01
# 5059                0.0 2016-01-01
# 6411                0.0 2016-01-01
# 7983                0.0 2016-01-01
# 8211                0.0 2016-01-01
# 8531                0.0 2016-01-01
# 8788                0.0 2016-01-01

# %%
two_df = twitch_df[twitch_df['Avg_channels'] == 2]
two_df.head(11)
# Out:
#        Rank                  Game  Month  Year  Hours_watched  Hours_streamed  \
# 4878     70      Final Fantasy IV      1  2016         535452            1158
# 5974    159  Grand Theft Auto III      1  2016         216252            1118
# 6141    187                Grid 2      1  2016         176713            1173
# 8694    165            Mega Man 2      1  2016         208756            1841
# 8697    183            Mega Man X      1  2016         180986            1415
# 8781    177     Metro: Last Light      1  2016         186279            1309
# 8790    143         Metroid Prime      1  2016         248704            1136
# 8958    164         Mirror's Edge      1  2016         209507            1528
# 9158    166           Move or Die      1  2016         202884            1275
# 10053    85           Paper Mario      1  2016         412453            1272
# 13447    83   Super Mario Bros. 3      1  2016         426084            1161
#
#        Peak_viewers  Peak_channels  Streamers  Avg_viewers  Avg_channels  \
# 4878         147048             31        186        720.0           2.0
# 5974         142392             22        222        291.0           2.0
# 6141          11348              9        348        238.0           2.0
# 8694         150406            121        319        281.0           2.0
# 8697         181667             22        322        243.0           2.0
# 8781          30280             13        439        250.0           2.0
# 8790         150677             25        146        334.0           2.0
# 8958         186567             35        501        282.0           2.0
# 9158          32211             12        319        273.0           2.0
# 10053        115905             16        216        554.0           2.0
# 13447        206252             17        308        573.0           2.0
#
#        Avg_viewer_ratio  Month_hours  Avg_channel_ratio       Date
# 4878             462.39          744               0.00 2016-01-01
# 5974             193.43          744               0.01 2016-01-01
# 6141             150.65          744               0.01 2016-01-01
# 8694             113.39          744               0.01 2016-01-01
# 8697             127.91          744               0.01 2016-01-01
# 8781             142.31          744               0.01 2016-01-01
# 8790             218.93          744               0.01 2016-01-01
# 8958             137.11          744               0.01 2016-01-01
# 9158             159.12          744               0.01 2016-01-01
# 10053            324.26          744               0.00 2016-01-01
# 13447            367.00          744               0.00 2016-01-01

# %%
plus_one = 1
X = twitch_df_X.Date + pd.DateOffset(months=plus_one)

# %%
twitch_df_X['one_month_future'] =  twitch_df_X.Date + pd.DateOffset(months=plus_one)
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_2572\2229078347.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   twitch_df_X['one_month_future'] =  twitch_df_X.Date + pd.DateOffset(months=plus_one)

# %%
twitch_df_X.head()
# Out:
#      Rank                      Game  Month  Year  Hours_watched  \
# 12    129             7 Days to Die      1  2016         269681
# 258   138                   Agar.io      1  2016         255617
# 264   142            Age of Empires      1  2016         248884
# 422   135          Alien: Isolation      1  2016         264294
# 477   108  American Truck Simulator      1  2016         314055
#
#      Hours_streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# 12            12131          4405             44       1240        362.0
# 258           20705          4183             74       4472        344.0
# 264             232        107455             18         40        335.0
# 422           11799          9590             42       3968        355.0
# 477             724         43089             48        186        422.0
#
#      Avg_channels  Avg_viewer_ratio  Month_hours  Avg_channel_ratio  \
# 12           16.0             22.23          744               0.04
# 258          28.0             12.35          744               0.08
# 264           0.0           1072.78          744               0.00
# 422          16.0             22.40          744               0.05
# 477           1.0            433.78          744               0.00
#
#           Date one_month_future
# 12  2016-01-01       2016-02-01
# 258 2016-01-01       2016-02-01
# 264 2016-01-01       2016-02-01
# 422 2016-01-01       2016-02-01
# 477 2016-01-01       2016-02-01

# %%
plus_three = 3
X3 = twitch_df_X.Date + pd.DateOffset(months=plus_three)

# %%
twitch_df_X['three_month_future'] =  twitch_df_X.Date + pd.DateOffset(months=plus_three)
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_2572\4009328254.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   twitch_df_X['three_month_future'] =  twitch_df_X.Date + pd.DateOffset(months=plus_three)

# %%
twitch_df_X.head()
# Out:
#      Rank                      Game  Month  Year  Hours_watched  \
# 12    129             7 Days to Die      1  2016         269681
# 258   138                   Agar.io      1  2016         255617
# 264   142            Age of Empires      1  2016         248884
# 422   135          Alien: Isolation      1  2016         264294
# 477   108  American Truck Simulator      1  2016         314055
#
#      Hours_streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# 12            12131          4405             44       1240        362.0
# 258           20705          4183             74       4472        344.0
# 264             232        107455             18         40        335.0
# 422           11799          9590             42       3968        355.0
# 477             724         43089             48        186        422.0
#
#      Avg_channels  Avg_viewer_ratio  Month_hours  Avg_channel_ratio  \
# 12           16.0             22.23          744               0.04
# 258          28.0             12.35          744               0.08
# 264           0.0           1072.78          744               0.00
# 422          16.0             22.40          744               0.05
# 477           1.0            433.78          744               0.00
#
#           Date one_month_future three_month_future
# 12  2016-01-01       2016-02-01         2016-04-01
# 258 2016-01-01       2016-02-01         2016-04-01
# 264 2016-01-01       2016-02-01         2016-04-01
# 422 2016-01-01       2016-02-01         2016-04-01
# 477 2016-01-01       2016-02-01         2016-04-01

# %%
plus_six = 6
X6 = twitch_df_X.Date + pd.DateOffset(months=plus_six)

# %%
twitch_df_X['six_month_future'] =  twitch_df_X.Date + pd.DateOffset(months=plus_six)
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_2572\3018229530.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   twitch_df_X['six_month_future'] =  twitch_df_X.Date + pd.DateOffset(months=plus_six)

# %%
twitch_df_X.head()
# Out:
#      Rank                      Game  Month  Year  Hours_watched  \
# 12    129             7 Days to Die      1  2016         269681
# 258   138                   Agar.io      1  2016         255617
# 264   142            Age of Empires      1  2016         248884
# 422   135          Alien: Isolation      1  2016         264294
# 477   108  American Truck Simulator      1  2016         314055
#
#      Hours_streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# 12            12131          4405             44       1240        362.0
# 258           20705          4183             74       4472        344.0
# 264             232        107455             18         40        335.0
# 422           11799          9590             42       3968        355.0
# 477             724         43089             48        186        422.0
#
#      Avg_channels  Avg_viewer_ratio  Month_hours  Avg_channel_ratio  \
# 12           16.0             22.23          744               0.04
# 258          28.0             12.35          744               0.08
# 264           0.0           1072.78          744               0.00
# 422          16.0             22.40          744               0.05
# 477           1.0            433.78          744               0.00
#
#           Date one_month_future three_month_future six_month_future
# 12  2016-01-01       2016-02-01         2016-04-01       2016-07-01
# 258 2016-01-01       2016-02-01         2016-04-01       2016-07-01
# 264 2016-01-01       2016-02-01         2016-04-01       2016-07-01
# 422 2016-01-01       2016-02-01         2016-04-01       2016-07-01
# 477 2016-01-01       2016-02-01         2016-04-01       2016-07-01

# %%
twitch_df_X.reset_index(drop = True, inplace = True)

# %%
#twitch_df_X one_mnth_hrs = twitch_df['hours_watched'] where twitch_df['Date'] == twitch_df one_month_future & twitch_df['Game']
# if it doesn't exist make it 0
# current strategy append the index and value as a dict, when there is a missing index value insert missing index and 0 lists, then convert to list, 
#and make the list the column hours_watched_omf
def f_hrs_watch (og_col_name, end_col_name):
    month_i = []
    month = []
    twitch_df_X_len = len(twitch_df_X)
    twitch_df_len = len(twitch_df)
    for i in range(twitch_df_X_len):
        for j in range(twitch_df_len):
            if twitch_df_X[og_col_name][i] == twitch_df['Date'][j] and twitch_df_X['Game'][i] == twitch_df['Game'][j]:
                month.append(twitch_df['Hours_watched'][j])
                month_i.append(i)
    zeros = []
    for i in range(twitch_df_X_len):
        if i not in month_i:
            zeros.append((i,0))
    merged_mth = list(zip(month_i, month))
    merged_z_mth = (merged_mth + zeros)
    merged_z_mth.sort()
    fin_mth = []
    for i in range(twitch_df_X_len):
        fin_mth.append(merged_z_mth[i][1])
    twitch_df_X[end_col_name] = fin_mth

# %%
f_hrs_watch('one_month_future', 'Hours_watched_1mth')
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_2572\3319501044.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   twitch_df_X[end_col_name] = fin_mth

# %%
twitch_df_X.describe()
# Out:
#               Rank        Month         Year  Hours_watched  Hours_streamed  \
# count  2025.000000  2025.000000  2025.000000   2.025000e+03    2.025000e+03
# mean    123.389136     4.402469  2018.737778   1.722624e+06    5.265007e+04
# std      53.193534     3.545371     2.247062   5.395172e+06    2.188540e+05
# min       1.000000     1.000000  2016.000000   9.246000e+04    1.900000e+01
# 25%      82.000000     1.000000  2017.000000   2.719870e+05    2.857000e+03
# 50%     130.000000     3.000000  2018.000000   6.132720e+05    1.046700e+04
# 75%     171.000000     7.000000  2021.000000   1.235417e+06    3.050200e+04
# max     200.000000    12.000000  2023.000000   9.437723e+07    4.948200e+06
#
#        Peak_viewers  Peak_channels      Streamers    Avg_viewers  \
# count  2.025000e+03    2025.000000    2025.000000    2025.000000
# mean   5.925928e+04     342.406420    7975.665679    2341.547654
# std    9.022342e+04    1071.912494   25987.858807    7321.015681
# min    7.470000e+02       2.000000       0.000000     126.000000
# 25%    1.644000e+04      26.000000     501.000000     369.000000
# 50%    3.332000e+04      76.000000    1802.000000     834.000000
# 75%    6.725600e+04     233.000000    5459.000000    1704.000000
# max    1.832845e+06   29306.000000  469399.000000  126851.000000
#
#        Avg_channels  Avg_viewer_ratio  Month_hours  Avg_channel_ratio  \
# count   2025.000000       2025.000000  2025.000000        2025.000000
# mean      71.471605        253.404770   733.179259           0.026716
# std      297.343688        808.080268    18.413132           0.035082
# min        0.000000          2.270000   672.000000           0.000000
# 25%        4.000000         31.420000   720.000000           0.010000
# 50%       14.000000         61.070000   744.000000           0.020000
# 75%       42.000000        148.010000   744.000000           0.030000
# max     6651.000000      11457.470000   744.000000           0.440000
#
#        Hours_watched_1mth
# count        2.025000e+03
# mean         1.009936e+06
# std          5.414015e+06
# min          0.000000e+00
# 25%          0.000000e+00
# 50%          0.000000e+00
# 75%          5.255080e+05
# max          1.459829e+08

# %%
twitch_df_X[twitch_df_X['Hours_watched_1mth'] != 0].describe()
# Out:
#              Rank       Month         Year  Hours_watched  Hours_streamed  \
# count  809.000000  809.000000   809.000000   8.090000e+02    8.090000e+02
# mean    93.032138    3.138443  2018.784920   3.173144e+06    1.082643e+05
# std     53.271967    2.998039     2.272461   8.149991e+06    3.359434e+05
# min      1.000000    1.000000  2016.000000   9.975600e+04    1.420000e+02
# 25%     49.000000    1.000000  2017.000000   4.677800e+05    9.610000e+03
# 50%     88.000000    1.000000  2019.000000   9.968500e+05    2.447200e+04
# 75%    134.000000    5.000000  2021.000000   2.443756e+06    7.501500e+04
# max    200.000000   11.000000  2023.000000   9.437723e+07    4.948200e+06
#
#        Peak_viewers  Peak_channels      Streamers    Avg_viewers  \
# count  8.090000e+02     809.000000     809.000000     809.000000
# mean   6.265248e+04     613.332509   15634.307787    4305.694685
# std    9.823830e+04    1566.066353   39187.339839   11055.673439
# min    7.470000e+02       5.000000       0.000000     148.000000
# 25%    1.388000e+04      58.000000    1510.000000     639.000000
# 50%    3.505000e+04     157.000000    4159.000000    1361.000000
# 75%    6.746900e+04     545.000000   12409.000000    3317.000000
# max    1.249796e+06   29306.000000  469399.000000  126851.000000
#
#        Avg_channels  Avg_viewer_ratio  Month_hours  Avg_channel_ratio  \
# count    809.000000        809.000000   809.000000         809.000000
# mean     146.789864         78.071632   735.100124           0.036230
# std      456.486165        147.354943    17.725663           0.039802
# min        0.000000          2.270000   672.000000           0.000000
# 25%       13.000000         22.820000   744.000000           0.010000
# 50%       33.000000         43.290000   744.000000           0.020000
# 75%      102.000000         83.080000   744.000000           0.040000
# max     6651.000000       2220.310000   744.000000           0.440000
#
#        Hours_watched_1mth
# count        8.090000e+02
# mean         2.527961e+06
# std          8.341568e+06
# min          9.313500e+04
# 25%          3.347160e+05
# 50%          7.779030e+05
# 75%          1.760360e+06
# max          1.459829e+08

# %%
f_hrs_watch('three_month_future', 'Hours_watched_3mth')
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_2572\3319501044.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   twitch_df_X[end_col_name] = fin_mth

# %%
f_hrs_watch('six_month_future', 'Hours_watched_6mth')
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_2572\3319501044.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   twitch_df_X[end_col_name] = fin_mth

# %%
twitch_df_X[twitch_df_X['Hours_watched_3mth'] != 0].describe()
# Out:
#              Rank       Month         Year  Hours_watched  Hours_streamed  \
# count  408.000000  408.000000   408.000000   4.080000e+02    4.080000e+02
# mean    87.306373    1.610294  2018.200980   4.026296e+06    1.419502e+05
# std     55.155236    1.603924     2.132883   1.022881e+07    3.902082e+05
# min      1.000000    1.000000  2016.000000   9.975600e+04    7.230000e+02
# 25%     41.750000    1.000000  2016.000000   3.932162e+05    1.096575e+04
# 50%     78.000000    1.000000  2018.000000   1.018976e+06    3.184700e+04
# 75%    129.000000    1.000000  2020.000000   3.134386e+06    1.077270e+05
# max    199.000000    9.000000  2022.000000   9.437723e+07    4.948200e+06
#
#         Peak_viewers  Peak_channels      Streamers    Avg_viewers  \
# count     408.000000     408.000000     408.000000     408.000000
# mean    58421.044118     572.556373   19069.176471    5420.556373
# std     98120.193932    1298.045564   41086.506267   13749.100259
# min       747.000000       5.000000       0.000000     148.000000
# 25%      8568.250000      53.750000    1538.500000     530.500000
# 50%     25098.000000     136.000000    4841.000000    1369.500000
# 75%     60421.750000     449.500000   15429.500000    4213.000000
# max    837094.000000   13547.000000  362233.000000  126851.000000
#
#        Avg_channels  Avg_viewer_ratio  Month_hours  Avg_channel_ratio  \
# count    408.000000        408.000000   408.000000         408.000000
# mean     191.031863         58.936078   738.823529           0.044853
# std      524.497482        108.273312    16.268878           0.045159
# min        1.000000          2.270000   672.000000           0.000000
# 25%       15.000000         17.097500   744.000000           0.010000
# 50%       43.000000         33.515000   744.000000           0.030000
# 75%      145.000000         66.270000   744.000000           0.060000
# max     6651.000000       1756.770000   744.000000           0.440000
#
#        Hours_watched_1mth  Hours_watched_3mth  Hours_watched_6mth
# count        4.080000e+02        4.080000e+02        4.080000e+02
# mean         3.648543e+06        3.584793e+06        3.185288e+06
# std          1.139423e+07        1.167837e+07        1.194609e+07
# min          0.000000e+00        9.507900e+04        0.000000e+00
# 25%          2.741142e+05        2.964690e+05        0.000000e+00
# 50%          8.665690e+05        7.984900e+05        4.228040e+05
# 75%          2.486220e+06        1.962135e+06        1.456344e+06
# max          1.459829e+08        1.286549e+08        1.520862e+08

# %%
twitch_df_X[twitch_df_X['Hours_watched_6mth'] != 0].describe()
# Out:
#              Rank       Month         Year  Hours_watched  Hours_streamed  \
# count  331.000000  331.000000   331.000000   3.310000e+02    3.310000e+02
# mean    86.117825    1.247734  2018.193353   4.408722e+06    1.589651e+05
# std     56.804407    0.758159     2.134582   1.117714e+07    4.267634e+05
# min      1.000000    1.000000  2016.000000   1.041330e+05    5.390000e+02
# 25%     36.500000    1.000000  2016.000000   4.295595e+05    1.326300e+04
# 50%     76.000000    1.000000  2018.000000   1.025337e+06    3.705600e+04
# 75%    131.500000    1.000000  2020.000000   3.166135e+06    1.188490e+05
# max    199.000000    6.000000  2022.000000   9.437723e+07    4.948200e+06
#
#         Peak_viewers  Peak_channels      Streamers    Avg_viewers  \
# count     331.000000     331.000000     331.000000     331.000000
# mean    60451.353474     579.000000   21321.108761    5932.320242
# std    104835.481296    1334.572514   44718.308613   15022.532924
# min       976.000000       5.000000       0.000000     155.000000
# 25%      8420.500000      52.000000    1535.000000     577.500000
# 50%     23330.000000     137.000000    5372.000000    1378.000000
# 75%     60488.500000     505.500000   18922.500000    4255.500000
# max    837094.000000   13547.000000  362233.000000  126851.000000
#
#        Avg_channels  Avg_viewer_ratio  Month_hours  Avg_channel_ratio  \
# count    331.000000        331.000000   331.000000         331.000000
# mean     213.830816         56.936435   739.141994           0.048459
# std      573.562959        114.026254    16.150460           0.050003
# min        1.000000          2.270000   672.000000           0.000000
# 25%       18.000000         16.055000   744.000000           0.020000
# 50%       50.000000         31.210000   744.000000           0.030000
# 75%      159.500000         62.705000   744.000000           0.060000
# max     6651.000000       1756.770000   744.000000           0.440000
#
#        Hours_watched_1mth  Hours_watched_3mth  Hours_watched_6mth
# count        3.310000e+02        3.310000e+02        3.310000e+02
# mean         3.985100e+06        4.143329e+06        4.019341e+06
# std          1.250719e+07        1.289292e+07        1.313176e+07
# min          0.000000e+00        0.000000e+00        1.141230e+05
# 25%          2.487805e+05        2.191970e+05        3.547190e+05
# 50%          7.750910e+05        8.508970e+05        7.948390e+05
# 75%          2.516366e+06        2.414040e+06        2.062492e+06
# max          1.459829e+08        1.286549e+08        1.520862e+08

# %%
twitch_gl_2022 = twitch_df_global[twitch_df_global['year'] == 2022]
twitch_gl_2022.head()
# Out:
#     year  Month  Hours_watched  Avg_viewers  Peak_viewers   Streams  \
# 72  2022      1     2162446961      2910426       5674002  27591148
# 73  2022      2     1983477130      2956001       5455266  24809831
# 74  2022      3     1934550137      2603701       4815581  25559363
# 75  2022      4     1869794288      2600548       5033040  23737853
# 76  2022      5     1894075075      2549226       5235525  22765370
#
#     Avg_channels  Games_streamed  Viewer_ratio
# 72        102254           41348         28.61
# 73        103548           40713         28.85
# 74         97461           41071         27.22
# 75         94164           42107         27.81
# 76         88227           42653         29.40

# %%
twitch_df_X.head()
# Out:
#    Rank                      Game  Month  Year  Hours_watched  Hours_streamed  \
# 0   129             7 Days to Die      1  2016         269681           12131
# 1   138                   Agar.io      1  2016         255617           20705
# 2   142            Age of Empires      1  2016         248884             232
# 3   135          Alien: Isolation      1  2016         264294           11799
# 4   108  American Truck Simulator      1  2016         314055             724
#
#    Peak_viewers  Peak_channels  Streamers  Avg_viewers  ...  Avg_viewer_ratio  \
# 0          4405             44       1240        362.0  ...             22.23
# 1          4183             74       4472        344.0  ...             12.35
# 2        107455             18         40        335.0  ...           1072.78
# 3          9590             42       3968        355.0  ...             22.40
# 4         43089             48        186        422.0  ...            433.78
#
#    Month_hours  Avg_channel_ratio       Date one_month_future  \
# 0          744               0.04 2016-01-01       2016-02-01
# 1          744               0.08 2016-01-01       2016-02-01
# 2          744               0.00 2016-01-01       2016-02-01
# 3          744               0.05 2016-01-01       2016-02-01
# 4          744               0.00 2016-01-01       2016-02-01
#
#   three_month_future six_month_future Hours_watched_1mth  Hours_watched_3mth  \
# 0         2016-04-01       2016-07-01             139365              212199
# 1         2016-04-01       2016-07-01             254146              198757
# 2         2016-04-01       2016-07-01                  0                   0
# 3         2016-04-01       2016-07-01             109754              122248
# 4         2016-04-01       2016-07-01            2134600              141057
#
#    Hours_watched_6mth
# 0             2063116
# 1                   0
# 2                   0
# 3                   0
# 4                   0
#
# [5 rows x 21 columns]

# %%
'Calculations for executive summary'
# Out:
# 'Calculations for executive summary'

# %%
sum(twitch_df['Hours_watched'])/sum(twitch_df_global['Hours_watched'])
# Out:
# 0.9120028311231916

# %%
def bottom_24_hrs(year, months):
    df = twitch_df[twitch_df['Year'] == year]
    df = df.sort_values(by = ['Hours_watched'])
    x = 0 
    for i in range(months):
        x_df = df[df['Month'] == i+1]
        x += sum(x_df['Hours_watched'][134:159])
    return(x)

# %%
a = bottom_24_hrs(2016, 12)
print(a)
b = bottom_24_hrs(2017, 12)
print(b)
c = bottom_24_hrs(2018, 12)
print(c)
d = bottom_24_hrs(2019, 12)
print(d)
e = bottom_24_hrs(2020, 12)
print(e)
f = bottom_24_hrs(2021, 12)
print(f)
g = bottom_24_hrs(2022, 12)
print(g)
h = bottom_24_hrs(2023, 3)
print(h)
# Out:
# 247434646
# 329737937
# 462041045
# 566562794
# 972581528
# 1359665565
# 1290313137
# 312489228

# %%
x = (a + b + c + d + e + f + g + h)
print(x)
# Out:
# 5540825880

# %%
x/sum(twitch_df_global['Hours_watched'])*100
# Out:
# 5.37499421247912

# %%
test = twitch_df_X.sort_values(by = ['Hours_watched'])
test.tail()
# Out:
#      Rank                Game  Month  Year  Hours_watched  Hours_streamed  \
# 538    10             FIFA 21      1  2021       55385122         1180415
# 420     3       Just Chatting      1  2019       59064487          803672
# 873     5     Hogwarts Legacy      2  2023       75887135         3567556
# 590     4  Escape from Tarkov      1  2022       93334264         1343113
# 76      1   League of Legends      1  2016       94377226         1362044
#
#      Peak_viewers  Peak_channels  Streamers  Avg_viewers  ...  \
# 538        837094           7733     137198      74442.0  ...
# 420        184542           1757     134201      79388.0  ...
# 873       1249796          29306     376515     109033.0  ...
# 590        690725           3186      71932     125449.0  ...
# 76         530270           2903     129172     126851.0  ...
#
#      Avg_viewer_ratio  Month_hours  Avg_channel_ratio       Date  \
# 538             46.92          744               0.02 2021-01-01
# 420             73.49          744               0.01 2019-01-01
# 873             21.27          696               0.05 2023-02-01
# 590             69.49          744               0.01 2022-01-01
# 76              69.29          744               0.01 2016-01-01
#
#     one_month_future three_month_future six_month_future Hours_watched_1mth  \
# 538       2021-02-01         2021-04-01       2021-07-01           37502320
# 420       2019-02-01         2019-04-01       2019-07-01           51698098
# 873       2023-03-01         2023-05-01       2023-08-01            4474134
# 590       2022-02-01         2022-04-01       2022-07-01           24312041
# 76        2016-02-01         2016-04-01       2016-07-01           93154772
#
#      Hours_watched_3mth  Hours_watched_6mth
# 538            31997488            14524522
# 420            58637850            60624575
# 873                   0                   0
# 590            14338993            38628111
# 76             88389049            77871713
#
# [5 rows x 21 columns]

# %%
twitch_df_noz = twitch_df_X[twitch_df_X['Hours_watched_1mth'] != 0]

# %%
sum(twitch_df_noz['Hours_watched_1mth'])/sum(twitch_df_noz['Hours_watched'])
# Out:
# 0.7966738567830425

# %%
twitch_df_noz_6 = twitch_df_X[twitch_df_X['Hours_watched_6mth'] != 0]

# %%
sum(twitch_df_noz_6['Hours_watched_6mth'])/sum(twitch_df_noz['Hours_watched'])
# Out:
# 0.5182561893598289

# %%
twitch_df_global.sort_values(by = ['Hours_watched'], inplace = True, ascending = False)
twitch_df_global.head(30)
# Out:
#     year  Month  Hours_watched  Avg_viewers  Peak_viewers   Streams  \
# 64  2021      5     2308295297      3106723       5835026  22761038
# 63  2021      4     2238018281      3112681       6291115  24406256
# 62  2021      3     2181654070      2936277       5270336  26207129
# 60  2021      1     2173794168      2925698       6516666  25614207
# 72  2022      1     2162446961      2910426       5674002  27591148
# 69  2021     10     2020197953      2718974       6170643  18209793
# 73  2022      2     1983477130      2956001       5455266  24809831
# 61  2021      2     1979581961      2950196       5274617  24319608
# 67  2021      8     1974586275      2657585       4778502  20767741
# 65  2021      6     1963630266      2731057       5775498  20285356
# 66  2021      7     1953900874      2629745       4415373  21055358
# 79  2022      8     1953185175      2628782       4839718  24299830
# 74  2022      3     1934550137      2603701       4815581  25559363
# 78  2022      7     1897296092      2553561       4500502  24625841
# 76  2022      5     1894075075      2549226       5235525  22765370
# 81  2022     10     1883320673      2534751       4610799  22867973
# 59  2020     12     1877319317      2526674       4860624  22089295
# 71  2021     12     1872400661      2520054       5014457  17824022
# 75  2022      4     1869794288      2600548       5033040  23737853
# 84  2023      1     1866962462      2512735       5593050  24429476
# 68  2021      9     1857514531      2583469       5630216  18826493
# 77  2022      6     1834839558      2551932       6707070  22837974
# 80  2022      9     1817119612      2527287       4678056  22278079
# 70  2021     11     1812117484      2520330       5969595  17415525
# 51  2020      4     1792309113      2492780       4455065  17814917
# 86  2023      3     1790507560      2409835       5314247  24408214
# 58  2020     11     1789235196      2488505       4380326  20176665
# 57  2020     10     1774145250      2387813       4208725  19774827
# 52  2020      5     1755760388      2363069       4043730  20203413
# 85  2023      2     1712025798      2551454       5364876  22482367
#
#     Avg_channels  Games_streamed  Viewer_ratio
# 64        110484           36960         28.69
# 63        115812           36196         27.58
# 62        117123           35759         25.79
# 60        119448           34551         25.03
# 72        102254           41348         28.61
# 69         91858           36406         30.39
# 73        103548           40713         28.85
# 61        122763           34594         24.67
# 67        100701           36471         26.70
# 65        101892           36099         27.38
# 66        101755           36319         26.27
# 79         93768           42610         28.37
# 74         97461           41071         27.22
# 78         94546           43566         27.30
# 76         88227           42653         29.40
# 81         90557           42164         28.35
# 59        107006           32840         24.61
# 71         90731           35577         28.04
# 75         94164           42107         27.81
# 84         93349           43611         27.44
# 68         95513           35861         27.29
# 77         90773           42096         28.36
# 80         90376           41863         28.37
# 70         90774           35043         27.99
# 51         93867           24646         26.79
# 86         93136           43944         26.25
# 58        103929           32479         24.45
# 57         95170           31922         25.99
# 52        100486           25396         23.77
# 85         96466           42440         26.58

# %%
twitch_df.head()
# Out:
#      Rank                      Game  Month  Year  Hours_watched  \
# 12    129             7 Days to Die      1  2016         269681
# 258   138                   Agar.io      1  2016         255617
# 264   142            Age of Empires      1  2016         248884
# 422   135          Alien: Isolation      1  2016         264294
# 477   108  American Truck Simulator      1  2016         314055
#
#      Hours_streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# 12            12131          4405             44       1240        362.0
# 258           20705          4183             74       4472        344.0
# 264             232        107455             18         40        335.0
# 422           11799          9590             42       3968        355.0
# 477             724         43089             48        186        422.0
#
#      Avg_channels  Avg_viewer_ratio  Month_hours  Avg_channel_ratio       Date
# 12           16.0             22.23          744               0.04 2016-01-01
# 258          28.0             12.35          744               0.08 2016-01-01
# 264           0.0           1072.78          744               0.00 2016-01-01
# 422          16.0             22.40          744               0.05 2016-01-01
# 477           1.0            433.78          744               0.00 2016-01-01

# %%
twitch_df_X.describe()
# Out:
#               Rank        Month         Year  Hours_watched  Hours_streamed  \
# count  2025.000000  2025.000000  2025.000000   2.025000e+03    2.025000e+03
# mean    123.389136     4.402469  2018.737778   1.722624e+06    5.265007e+04
# std      53.193534     3.545371     2.247062   5.395172e+06    2.188540e+05
# min       1.000000     1.000000  2016.000000   9.246000e+04    1.900000e+01
# 25%      82.000000     1.000000  2017.000000   2.719870e+05    2.857000e+03
# 50%     130.000000     3.000000  2018.000000   6.132720e+05    1.046700e+04
# 75%     171.000000     7.000000  2021.000000   1.235417e+06    3.050200e+04
# max     200.000000    12.000000  2023.000000   9.437723e+07    4.948200e+06
#
#        Peak_viewers  Peak_channels      Streamers    Avg_viewers  \
# count  2.025000e+03    2025.000000    2025.000000    2025.000000
# mean   5.925928e+04     342.406420    7975.665679    2341.547654
# std    9.022342e+04    1071.912494   25987.858807    7321.015681
# min    7.470000e+02       2.000000       0.000000     126.000000
# 25%    1.644000e+04      26.000000     501.000000     369.000000
# 50%    3.332000e+04      76.000000    1802.000000     834.000000
# 75%    6.725600e+04     233.000000    5459.000000    1704.000000
# max    1.832845e+06   29306.000000  469399.000000  126851.000000
#
#        Avg_channels  Avg_viewer_ratio  Month_hours  Avg_channel_ratio  \
# count   2025.000000       2025.000000  2025.000000        2025.000000
# mean      71.471605        253.404770   733.179259           0.026716
# std      297.343688        808.080268    18.413132           0.035082
# min        0.000000          2.270000   672.000000           0.000000
# 25%        4.000000         31.420000   720.000000           0.010000
# 50%       14.000000         61.070000   744.000000           0.020000
# 75%       42.000000        148.010000   744.000000           0.030000
# max     6651.000000      11457.470000   744.000000           0.440000
#
#        Hours_watched_1mth  Hours_watched_3mth  Hours_watched_6mth
# count        2.025000e+03        2.025000e+03        2.025000e+03
# mean         1.009936e+06        7.222694e+05        6.569886e+05
# std          5.414015e+06        5.430806e+06        5.506891e+06
# min          0.000000e+00        0.000000e+00        0.000000e+00
# 25%          0.000000e+00        0.000000e+00        0.000000e+00
# 50%          0.000000e+00        0.000000e+00        0.000000e+00
# 75%          5.255080e+05        0.000000e+00        0.000000e+00
# max          1.459829e+08        1.286549e+08        1.520862e+08

# %%
twitch_df_X.drop(['Rank', 'Month_hours', 'Avg_viewer_ratio'], axis = 1, inplace = True)
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_2572\2951507504.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   twitch_df_X.drop(['Rank', 'Month_hours', 'Avg_viewer_ratio'], axis = 1, inplace = True)

# %%
twitch_df.to_pickle('twitch_df_og.pkl')

# %%
twitch_df_X.to_pickle('twitch_df_wrng.pkl')
